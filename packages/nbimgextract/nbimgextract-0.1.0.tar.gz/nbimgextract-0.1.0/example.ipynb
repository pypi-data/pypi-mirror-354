# %%
from __future__ import annotations

from IPython.display import Image, SVG

# %%
Image(filename="test-imgs/Example_gif.gif")

# %%
Image(filename="test-imgs/Example_png.png")

# %%
Image(filename="test-imgs/Example_webp.webp")

# %%
Image(filename="test-imgs/Example_jpg.jpg")

# %%
SVG(filename="test-imgs/Triangle-right-abchpq.svg")

# %% [markdown]
# # I am a markdown cell

# %% [raw]
# I am a raw cell
